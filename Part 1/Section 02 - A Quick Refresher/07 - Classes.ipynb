# %% [markdown]
# ## Custom Classes

# %% [markdown]
# To create a custom class we use the `class` keyword, and we can initialize class attributes in the special method `__init__`.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height

# %% [markdown]
# We create **instances** of the `Rectangle` class by calling it with arguments that are passed to the `__init__` method as the second and third arguments. The first argument (`self`) is automatically filled in by Python and contains the object being created.
#
# Note that using `self` is just a convention

# %%
r1 = Rectangle(100, 200)

# %%
r1.width
# Out:
# 100

# %%
r1.height
# Out:
# 200

# %% [markdown]
# `width` and `height` are attributes of the `Rectangle` class. But since they are just values (not callables), we call them **properties**.
#
# Attributes that are callables are called **methods**.
#
# <hr>
# We can add callable attributes to our class (methods), that will also be referenced using the dot notation.
#
# Again, we will create instance methods, which means the method will require the first argument to be the object being used when the method is called.

# %%
class Rectangle:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)

# %%
r1 = Rectangle(10, 20)

# %%
print(r1.width, r1.height, r1.area(), r1.perimeter(), sep='\n')
# Out:
# 10
# 20
# 200
# 60

# %%
r1.area()
# Out:
# 200

# %% [markdown]
# When we ran the above line of code, our object was `r1`, so when `area` was called, Python in fact called the method `area` in the Rectangle class automatically passing `r1` to the `self` parameter.
# <hr>
# This is why we can use a name other than self, such as in the perimeter method:

# %%
r1.perimeter()
# Out:
# 60

# %% [markdown]
# # str()

# %%
str(r1)
# because we have no __str__() method 
# and str() returns class name and memory address
# Out:
# '<__main__.Rectangle object at 0x7fd826c31e10>'

# %%
hex(id(r1))
# memory address of r1
# The id() function returns a unique id
# if we convert id of object to hex() returns memory address
# Out:
# '0x7fd826c31e10'

# %%
id(r1)
# Out:
# 140566339984912

# %% [markdown]
# Python defines a bunch of **special** methods that we can use to give our classes functionality that resembles functionality of built-in and standard library objects.
#
# <hr>
#
# For example, we can obtain the string representation of an integer using the built-in `str` function:

# %%
str(10)
# Out:
# '10'

# %% [markdown]
# What happens if we try this with our Rectangle object?

# %%
str(r1)
#Not exactly what we might have expected. On the other hand, how is Python supposed to know how to display our rectangle as a string?

#We could write a method in the class such as:
# Out:
# '<__main__.Rectangle object at 0x7fd826c31e10>'

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def to_string(self):
        return f'Rctangle: width={self.width}, height={self.height}'

# %% [markdown]
# So now we could get a string from our object as follows:

# %%
r2 = Rectangele(20, 10)

# %%
r2.to_string()
# Out:
# 'Rctangle: width=20, height=10'

# %% [markdown]
# But of course, using the built-in `str` function still does not work:

# %%
str(r2)
# str() by default going to look at the class and the memory address of the object 
# we can overwrite and provide your definition for string() with special method __str__()
# Out:
# '<__main__.Rectangele object at 0x7fd826c30d60>'

# %% [markdown]
# When we call `str(r1)`, Python will first look to see if our class (`Rectangle`) has a special method called `__str__`.
#
# If the `__str__` method is present, then Python will call it and return that value.

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

# %%
r2 = Rectangele(10, 20)

# %%
str(r2)
# Out:
# 'Rctangle: width=10, height=20'

# %%
print(r2)
# Out:
# Rctangle: width=10, height=20

# %% [markdown]
# However, in Jupyter (and interactive console if you are using that), look what happens here:

# %%
print(repr(r2))
# or
r2
# if we call the object this way what happens is that it's still going to return this
# Out:
# <__main__.Rectangele object at 0x7fd826c32080>

# %%
# that's not the functionality we get if we have a list
l = [1, 2, 3]

# %%
#we can convert a list to a string
list(l)
# Out:
# [1, 2, 3]

# %%
# or we can also just do this
l
# it's not telling us "this is a list that some address"
# Out:
# [1, 2, 3]

# %% [markdown]
# As you can see we still get that default. That's because here Python is not converting `r1` to a string, but instead looking for a string *representation* of the object. It is looking for the `__repr__` method (which we'll come back to later).

# %%
# it's a different special method that we need to implement
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

# %%
r2 = Rectangele(10 , 20)

# %%
print(repr(r2))
# or
r2
# and we fix it
# Out:
# Rectangele(10, 20)
# Rectangele(10, 20)

# %% [markdown]
# ### equality

# %%
r1 = Rectangele(10, 20)
r2 = Rectangele(10, 20)

# %%
r1 is not r2
# there are different memory addresses, the different objects, different instance of the class
# Out:
# True

# %%
r1 == r2
# if it's got the same width and height, its the same thing
# we can do that with __eq__()
# Out:
# False

# %% [markdown]
# We just need to tell Python how to do it, using the special method `__eq__`.

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

    def __eq__(self, other):
        return self.width == other.width and self.height == other.height

# %%
r1 = Rectangele(10, 20)
r2 = Rectangele(10, 20)
r1 == r2
# Out:
# True

# %% [markdown]
# And if we try to compare our Rectangle to a different type:

# %%
r2 == 100
# int object don't have width and height properties
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 51' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000050?line=0'>1</a> r2 == 100
#
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 48' in Rectangele.__eq__(self, other)
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000047?line=17'>18</a> def __eq__(self, other):
# ---> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000047?line=18'>19</a>     return self.width == other.width and self.height == other.height
#
# AttributeError: 'int' object has no attribute 'width'

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

    def __eq__(self, other):
        if isinstance(other, Rectangele):
            return self.width == other.width and self.height == other.height
        else:
            return False

# %%
r1 = Rectangele(10, 20)
r2 = Rectangele(10, 20)

# %%
r1 == r2
# Out:
# True

# %%
r1 == 100
# Out:
# False

# %% [markdown]
# What about `<`, `>`, `<=`, etc.?
#
# Again, Python has special methods we can use to provide that functionality.
#
# These are methods such as `__lt__`, `__gt__`, `__le__`, etc.

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height
    
    def area(self):
        return self.width * self.height
    
    def perimeter(self):
        return 2 * (self.width + self.height)
    
    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

    def __eq__(self, other):
        if isinstance(other, Rectangele):
            return self.width == other.width and self.height == other.height
        else:
            return False
    def __lt__(self, other):
        if isinstance(other, Rectangele):
            return self.area() < other.area()
        else:
            return NotImplemented

# %%
r1 = Rectangele(10, 20)
r2 = Rectangele(100, 20)

# %%
r1 < r2
# Out:
# True

# %%
r2 < r1
# Out:
# False

# %%
r2 > r1
# Out:
# True

# %% [markdown]
# How did that work? We did not define a `__gt__` method.
#
# Well, Python cleverly decided that since `r1 > r2` was not implemented, it would give
#
# `r2 < r1`
#
# a try. And since, `__lt__` **is** defined, it worked!

# %%
r1 < r2
# we don't implement __gt__() but in here it works
# because python says ok r1 if less than r2 (r1 < r2) --> TRUE, so r2 is greater then r1 (r2 > r1) --> True
# Out:
# True

# %% [markdown]
# Of course, `<=` is not going to magically work!

# %%
r1 <= r2
# but it's not supported 
# we should implement that
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 65' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000064?line=0'>1</a> r1 <= r2
#
# TypeError: '<=' not supported between instances of 'Rectangele' and 'Rectangele'

# %% [markdown]
# ## geter and setter

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

    def __eq__(self, other):
        if isinstance(other, Rectangele):
            return self.width == other.width and self.height == other.height
        else:
            return False

# %%
r1 = Rectangele(10, 200)

# %% [markdown]
# #### A few things going on here
# ##### I explain it in comments

# %%
r1.width
# in here where allowing direct access to the width property(and height as well)
# Out:
# 10

# %%
r1.width = -100
# users can set this to negetive number
# we want to put logic in here that stops pepole from setting the width and height to negative value
# it doesn't make sense of a retangle with a negative with and height

# %%
r1
# Out:
# Rectangele(-100, 200)

# %% [markdown]
# #### The way we do that is we implement methods to get and set the properties

# %% [markdown]
# We don't  privet variables in python.
# Instead this is a **convention** if we put a <u>underscore</u> in front of our variable names, in front of our properties and same thing with the methods -> we are telling **this is a privet variable**
# but if they want to change, they can

# %%
class Rectangele:
    def __init__(self, width, height):
        self._width = width
        self._height = height

    def get_width(self):
        return self._width
    
    def set_width(self, width):
        if width <= 0:
            raise ValueError('width must be positive.')
        else:
            self._width = width

    def __str__(self):
        return f'Rctangle: width={self._width}, height={self._height}'

    def __repr__(self):
        return f'Rectangele({self._width}, {self._height})'

    def __eq__(self, other):
        if isinstance(other, Rectangele):
            return self._width == other._width and self._height == other._height
        else:
            return False

# %%
r1 = Rectangele(10, 20)

# %%
r1.width
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 77' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000086?line=0'>1</a> r1.width
#
# AttributeError: 'Rectangele' object has no attribute 'width'

# %%
r1.width = -20
r1.width
# why this happens? because we added a property called >r1.width< (monkey patching)
# Out:
# -20

# %%
# r1.width is -20 but let's see Rectangle
r1
# width does not change
# Out:
# Rectangele(10, 20)

# %%
# this the way should be accessing to width
r1.get_width()
# Out:
# 10

# %%
# to set the width we have to use the set_width property
r1.set_width(-10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 81' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000090?line=0'>1</a> # to set the width we have to use the set_width property
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000090?line=1'>2</a> r1.set_width(-10)
#
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 75' in Rectangele.set_width(self, width)
#       <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000080?line=8'>9</a> def set_width(self, width):
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000080?line=9'>10</a>     if width <= 0:
# ---> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000080?line=10'>11</a>         raise ValueError('width must be positive.')
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000080?line=11'>12</a>     else:
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000080?line=12'>13</a>         self._width = width
#
# ValueError: width must be positive.

# %%
# we have ValueError (the width must be positive)
r1.set_width(30)

# %%
r1
# Out:
# Rectangele(30, 20)

# %% [markdown]
# There are more things we should do to properly implement all this, in particular we should also be checking the positive and negative values during the `__init__` phase. We do so by using the accessor methods for height and width:

# %% [markdown]
#  in python unless you know that you have a specific reason to actually implement a specific getter  of setter(that has extra logic) you don't implement them, you just leave the properties bar that way.
#  First of all there's no such thing as private variable
#   Secondly is don't force people to use a **getter** and **setter** unless they have to

# %%
class Rectangele:
    def __init__(self, width, height):
        self.width = width
        self.height = height

    # i have a property that goes through a method for the getter without breaking backward compatibility
    @property
    def width(self):
        return self._width

    @width.setter
    def width(self, width):
        if width <= 0:
            raise ValueError('Width must be positive.')
        else:
            self._width = width

    @property
    def height(self):
        return self._height

    @height.setter
    def height(self, height):
        if height <= 0:
            raise ValueError('Hight must be positive.')
        else:
            self._height = height


    def __str__(self):
        return f'Rctangle: width={self.width}, height={self.height}'

    def __repr__(self):
        return f'Rectangele({self.width}, {self.height})'

    def __eq__(self, other):
        if isinstance(other, Rectangele):
            return self.width == other.width and self.height == other.height
        else:
            return False

# %%
r1 = Rectangele(10, 20)

# %% [markdown]
# r1.

# %%
r1.height = 100
r1
# Out:
# Rectangele(10, 100)

# %%
r1.height = -1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 90' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000102?line=0'>1</a> r1.height = -1
#
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 86' in Rectangele.height(self, height)
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=21'>22</a> @height.setter
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=22'>23</a> def height(self, height):
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=23'>24</a>     if height <= 0:
# ---> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=24'>25</a>         raise ValueError('Hight must be positive.')
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=25'>26</a>     else:
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=26'>27</a>         self._height = height
#
# ValueError: Hight must be positive.

# %%
str(r1)
# Out:
# 'Rctangle: width=10, height=100'

# %%
r1 = Rectangele(-100, 200)
r1
# becuse in __init__() method, attributes are like this -> self._width AND self._height
# to fix this I change attributes to -> self.width AND self.height
# Out:
# Rectangele(-100, 200)

# %%
r1 = Rectangele(-100, 200)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 93' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000106?line=0'>1</a> r1 = Rectangele(-100, 200)
#
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 86' in Rectangele.__init__(self, width, height)
#       <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=1'>2</a> def __init__(self, width, height):
# ----> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=2'>3</a>     self.width = width
#       <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=3'>4</a>     self.height = height
#
# /home/dev/python-deepdive/Part 1/Section 02 - A Quick Refresher/07 - Classes.ipynb Cell 86' in Rectangele.width(self, width)
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=10'>11</a> @width.setter
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=11'>12</a> def width(self, width):
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=12'>13</a>     if width <= 0:
# ---> <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=13'>14</a>         raise ValueError('Width must be positive.')
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=14'>15</a>     else:
#      <a href='vscode-notebook-cell:/home/dev/python-deepdive/Part%201/Section%2002%20-%20A%20Quick%20Refresher/07%20-%20Classes.ipynb#ch0000096?line=15'>16</a>         self._width = width
#
# ValueError: Width must be positive.
